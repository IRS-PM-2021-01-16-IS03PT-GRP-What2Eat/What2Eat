# %%
import pandas as pd

# %%
df = pd.read_json("results.json",orient='index')

# %%
df
# Out:
#                                                  Title  \
# 0    How to make Pulut Durian (Durian with Sticky R...
# 1                              How to make Salted Eggs
# 2                 Quick & Easy Pumkin Ice Cream Recipe
# 3                               Malay Hot Curried Crab
# 4                             How to make Tartar Sauce
# ..                                                 ...
# 169         How to make Fried Crabs w-Salted egg yolks
# 170                     How to make Green Papaya Salad
# 171            Crispy Cashew Nuts (Icing Sugar, Spicy)
# 172        How to make Ice Cendol (Chendol, Es Cendol)
# 173                     How to make Cinnamon Ice Cream
#
#                                                  Image  \
# 0    https://singaporelocalfavourites.com/wp-conten...
# 1    https://singaporelocalfavourites.com/wp-conten...
# 2    https://singaporelocalfavourites.com/wp-conten...
# 3    https://singaporelocalfavourites.com/wp-conten...
# ...

# %%
df.to_csv('What2Eat-singaporeanlocalfavourtes.csv')
